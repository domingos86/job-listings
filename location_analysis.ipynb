# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import csv, time

# %%
job_locations = pd.DataFrame()
for source in ['indeed', 'dice']:
    job_locations = job_locations.append(pd.read_csv('data/' + source + '_cleaned.csv',
                                                     usecols = ['job_id', 'title', 'date_posted', 'location']))

# %%
len(job_locations)
# Out:
# 66702

# %%
locations = job_locations[['location']].drop_duplicates()

# %%
len(locations)
# Out:
# 4636

# %%
geolocator = Nominatim()
def geolocate(x):
    try:
        time.sleep(0.2)
        return geolocator.geocode(x)
    except:
        return None
locations['geolocation'] = locations['location'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                location geolocation
# 238                               Minneapolis, MN 55428        None
# 270                                    Dallas, TX 75390        None
# 392                                  New York, NY 10167        None
# 475                                    Austin, TX 73344        None
# 768                                Santa Cruz, CA 95064        None
# 856                                     Plano, TX 75086        None
# 871                             Mountain View, CA 94039        None
# 1475                          Hoffman Estates, IL 60179        None
# 1931                              Minneapolis, MN 55438        None
# 2299                                 Longmont, CO 80502        None
# 2522                                  Madison, WI 53744        None
# 2665                              Santa Clara, CA 95053        None
# 821    On Site At Client's Main Office In Hillsboro, OR        None
# ...

# %% [markdown]
# Got banned... apparently their policy states no more than 1 request per second. Will try again from a different connection.

# %%
geolocator = Nominatim()
def geolocate(x):
    try:
        location = geolocator.geocode(x)
        time.sleep(1)
        return location
    except:
        return None
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'location'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation
# 238                                Minneapolis, MN 55428        None
# 270                                     Dallas, TX 75390        None
# 475                                     Austin, TX 73344        None
# 856                                      Plano, TX 75086        None
# 871                              Mountain View, CA 94039        None
# 1475                           Hoffman Estates, IL 60179        None
# 1931                               Minneapolis, MN 55438        None
# 2299                                  Longmont, CO 80502        None
# 2522                                   Madison, WI 53744        None
# 2665                               Santa Clara, CA 95053        None
# 821     On Site At Client's Main Office In Hillsboro, OR        None
# 838                        Nyu Langone Health System, NY        None
# 960                          Sr. Solutions Architect, AZ        None
# ...

# %%
locations['corrected'] = locations['location']

# %%
locations.loc[63083, 'corrected'] = 'New Jersey, US'
locations.loc[62806, 'corrected'] = 'Philadelphia, PA'
locations.loc[58311, 'corrected'] = 'Brooklyn, NY'
locations.loc[58014, 'corrected'] = 'Washington, DC'
locations.loc[57733, 'corrected'] = 'Hickam, HI'
locations.loc[56099, 'corrected'] = 'Missouri, US'
locations.loc[55200, 'corrected'] = 'New York, NY'
locations.loc[53916, 'corrected'] = 'Tysons corner, VA'
locations.loc[51816, 'corrected'] = 'Woods Cross, Utah'
locations.loc[50211, 'corrected'] = 'Portland, ME'
locations.loc[48495, 'corrected'] = 'Brooklyn, NY'
locations.loc[48256, 'corrected'] = 'Industry, CA'
locations.loc[47842, 'corrected'] = 'Commerce, CA'
locations.loc[46359, 'corrected'] = 'Sergeant Bluff, IA'
locations.loc[45886, 'corrected'] = 'Torrance, CA'
locations.loc[45852, 'corrected'] = 'Lexington Park, MD'
locations.loc[44972, 'corrected'] = 'Louisiana, US'
locations.loc[44875, 'corrected'] = 'Archbold, OH'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation  \
# 238                                Minneapolis, MN 55428        None
# 270                                     Dallas, TX 75390        None
# 475                                     Austin, TX 73344        None
# 856                                      Plano, TX 75086        None
# 871                              Mountain View, CA 94039        None
# 1475                           Hoffman Estates, IL 60179        None
# 1931                               Minneapolis, MN 55438        None
# 2299                                  Longmont, CO 80502        None
# 2522                                   Madison, WI 53744        None
# 2665                               Santa Clara, CA 95053        None
# 821     On Site At Client's Main Office In Hillsboro, OR        None
# 838                        Nyu Langone Health System, NY        None
# 960                          Sr. Solutions Architect, AZ        None
# ...

# %%
def geolocate(x):
    if not x:
        return None
    try:
        location = geolocator.geocode(x)
        time.sleep(1)
        return location
    except:
        return None
locations['corrected'] = ''
locations.loc[53587, 'corrected'] = 'Santa Barbara, CA'
locations.loc[52963, 'corrected'] = 'WI, US'
locations.loc[52043, 'corrected'] = 'Schaumburg, IL'
locations.loc[51963, 'corrected'] = 'IL, US'
locations.loc[45571, 'corrected'] = 'Trenton, NJ'
locations.loc[44839, 'corrected'] = 'Mechanicsburg, PA'
locations.loc[44201, 'corrected'] = 'Sebastopol, CA'
locations.loc[40733, 'corrected'] = 'Milwaukee, WI'
locations.loc[40556, 'corrected'] = 'Deerfield Beach, FL'
locations.loc[40485, 'corrected'] = 'Des Moines, IA'
locations.loc[40415, 'corrected'] = 'Somerset, NJ'
locations.loc[40366, 'corrected'] = 'Bridgewater, NJ'
locations.loc[40015, 'corrected'] = 'CT, US'
locations.loc[39139, 'corrected'] = 'FL, US'
locations.loc[35485, 'corrected'] = 'Dahlgren, VA'
locations.loc[35470, 'corrected'] = 'Jacksonville, FL'
locations.loc[34805, 'corrected'] = 'Bedford, MA'
locations.loc[4737, 'corrected'] = 'NC, US'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation corrected
# 238                                Minneapolis, MN 55428        None
# 270                                     Dallas, TX 75390        None
# 475                                     Austin, TX 73344        None
# 856                                      Plano, TX 75086        None
# 871                              Mountain View, CA 94039        None
# 1475                           Hoffman Estates, IL 60179        None
# 1931                               Minneapolis, MN 55438        None
# 2299                                  Longmont, CO 80502        None
# 2522                                   Madison, WI 53744        None
# 2665                               Santa Clara, CA 95053        None
# 821     On Site At Client's Main Office In Hillsboro, OR        None
# 838                        Nyu Langone Health System, NY        None
# ...

# %%
locations.loc[238, 'corrected'] = 'Minneapolis, MN'
locations.loc[270, 'corrected'] = 'Dallas, TX'
locations.loc[35652, 'corrected'] = 'ON, Canada'
locations.loc[34184, 'corrected'] = 'Minot, ND'
locations.loc[33762, 'corrected'] = 'American Fork, UT'
locations.loc[30794, 'corrected'] = 'Malvern, PA'
locations.loc[29027, 'corrected'] = 'Fort worth, TX'
locations.loc[28881, 'corrected'] = 'San Francisco, CA'
locations.loc[27632, 'corrected'] = 'O\'fallon, IL'
locations.loc[26175, 'corrected'] = 'O\'fallon, MO'
locations.loc[25449, 'corrected'] = 'Newport News, VA'
locations.loc[24591, 'corrected'] = 'College station, TX'
locations.loc[24195, 'corrected'] = 'Wilmington, DE'
locations.loc[475, 'corrected'] = 'Austin, TX'
locations.loc[856, 'corrected'] = 'Plano, TX'
locations.loc[871, 'corrected'] = 'Mountain View, CA'
locations.loc[1475, 'corrected'] = 'Hoffman Estates, IL'
locations.loc[1931, 'corrected'] = 'Minneapolis, MN'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation corrected
# 2299                                  Longmont, CO 80502        None
# 2522                                   Madison, WI 53744        None
# 2665                               Santa Clara, CA 95053        None
# 821     On Site At Client's Main Office In Hillsboro, OR        None
# 838                        Nyu Langone Health System, NY        None
# 960                          Sr. Solutions Architect, AZ        None
# 1119                     Bethlehem Or Nyc Or Holmdel, NY        None
# 1163                                     unspecified, NY        None
# 1285                                   Baden-w-rttemberg        None
# 1483                              Denver/minneapolis, CO        None
# 1852               X-international-international Posting        None
# 1884                                   Mediacom Park, NY        None
# ...

# %%
locations = locations.drop([52867, 48709, 40417, 36005, 27917, 25579, 24326, 23498, 22479, 21000, 18847, 1285])
mask = locations['geolocation'].isnull()
locations.loc[2299, 'corrected'] = 'Longmont, CO'
locations.loc[2522, 'corrected'] = 'Madison, WI'
locations.loc[2665, 'corrected'] = 'Santa Clara, CA'
locations.loc[821, 'corrected'] = 'Hillsboro, OR'
locations.loc[838, 'corrected'] = '550 1st Avenue, New York, NY'
locations.loc[20633, 'corrected'] = 'Hickam, HI'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation corrected
# 960                          Sr. Solutions Architect, AZ        None
# 1119                     Bethlehem Or Nyc Or Holmdel, NY        None
# 1163                                     unspecified, NY        None
# 1483                              Denver/minneapolis, CO        None
# 1852               X-international-international Posting        None
# 1884                                   Mediacom Park, NY        None
# 2035                                     Unspecified, NY        None
# 2995                           Blue Cross Group Hosp, DC        None
# 3266                                        Hooksett, AZ        None
# 3370                     Purchase, Ny Or Phoenix, Az, NY        None
# 3494                                  Resrch Tri Prk, NC        None
# 3640                         Tacoma, Wa & Aurora, Co, WA        None
# ...

# %%
locations = locations.drop([41201, 38451, 20623, 17975, 17559, 16670, 17177, 17249, 17374, 1852])
mask = locations['geolocation'].isnull()
locations.loc[61249, 'corrected'] = 'NJ, US'
locations.loc[40839, 'corrected'] = 'NJ, US'
locations.loc[34459, 'corrected'] = 'GA, US'
locations.loc[19793, 'corrected'] = 'Philadelphia, PA'
locations.loc[19701, 'corrected'] = 'Towson, MD'
locations.loc[18568, 'corrected'] = 'Montreal, QC'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
locations = locations.drop([15873, 15481, 15594, 15669])
mask = locations['geolocation'].isnull()
locations.loc[12624, 'corrected'] = 'Bellevue, WA'
locations.loc[15101, 'corrected'] = 'Industry, CA'
locations.loc[19428, 'corrected'] = 'Alpharetta, GA'
locations.loc[18410, 'corrected'] = 'Chicago, IL'
locations.loc[17611, 'corrected'] = 'Washington, DC'
locations.loc[17548, 'corrected'] = 'Chicago, IL'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation corrected
# 960                          Sr. Solutions Architect, AZ        None
# 1119                     Bethlehem Or Nyc Or Holmdel, NY        None
# 1163                                     unspecified, NY        None
# 1483                              Denver/minneapolis, CO        None
# 1884                                   Mediacom Park, NY        None
# 2035                                     Unspecified, NY        None
# 2995                           Blue Cross Group Hosp, DC        None
# 3266                                        Hooksett, AZ        None
# 3370                     Purchase, Ny Or Phoenix, Az, NY        None
# 3494                                  Resrch Tri Prk, NC        None
# 3640                         Tacoma, Wa & Aurora, Co, WA        None
# 4569   Satellite Office; North America-us-illinois; N...        None
# ...

# %%
locations = locations.drop([13774])
mask = locations['geolocation'].isnull()
locations.loc[12588, 'corrected'] = 'O\'fallon, MO'
locations.loc[17421, 'corrected'] = 'Orange County, CA'
locations.loc[15991, 'corrected'] = 'John C. Stennis Space Center, MS'
locations.loc[15169, 'corrected'] = 'Halawa, HI'
locations.loc[14027, 'corrected'] = 'West Valley City, UT'
locations.loc[13421, 'corrected'] = 'Liberty Lake, ON'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation corrected
# 960                          Sr. Solutions Architect, AZ        None
# 1119                     Bethlehem Or Nyc Or Holmdel, NY        None
# 1163                                     unspecified, NY        None
# 1483                              Denver/minneapolis, CO        None
# 1884                                   Mediacom Park, NY        None
# 2035                                     Unspecified, NY        None
# 2995                           Blue Cross Group Hosp, DC        None
# 3266                                        Hooksett, AZ        None
# 3370                     Purchase, Ny Or Phoenix, Az, NY        None
# 3494                                  Resrch Tri Prk, NC        None
# 3640                         Tacoma, Wa & Aurora, Co, WA        None
# 4569   Satellite Office; North America-us-illinois; N...        None
# ...

# %%
#locations = locations.drop([13774])
#mask = locations['geolocation'].isnull()
locations.loc[13153, 'corrected'] = 'TX, US'
locations.loc[12423, 'corrected'] = 'Jersey City, NJ'
locations.loc[11485, 'corrected'] = 'New York, NY'
locations.loc[11008, 'corrected'] = 'New York, NY'
locations.loc[9756, 'corrected'] = 'MA,US'
locations.loc[8059, 'corrected'] = 'Chicago, IL'
locations.loc[7950, 'corrected'] = 'Morrisville, NC'
locations.loc[8801, 'corrected'] = 'Bellevue, WA'
locations.loc[7585, 'corrected'] = 'Los Angeles, CA'
locations.loc[7406, 'corrected'] = 'TX, US'
locations.loc[7343, 'corrected'] = 'Grand Rapids, MI'
locations.loc[5929, 'corrected'] = 'Aberdeen Proving Ground, MD'
locations.loc[5649, 'corrected'] = 'Patuxent River NAS, MD'
locations.loc[5338, 'corrected'] = 'Minneapolis, MN'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                                 location geolocation corrected
# 960                          Sr. Solutions Architect, AZ        None
# 1119                     Bethlehem Or Nyc Or Holmdel, NY        None
# 1163                                     unspecified, NY        None
# 1483                              Denver/minneapolis, CO        None
# 1884                                   Mediacom Park, NY        None
# 2035                                     Unspecified, NY        None
# 2995                           Blue Cross Group Hosp, DC        None
# 3266                                        Hooksett, AZ        None
# 3370                     Purchase, Ny Or Phoenix, Az, NY        None
# 3494                                  Resrch Tri Prk, NC        None
# 3640                         Tacoma, Wa & Aurora, Co, WA        None
# 4569   Satellite Office; North America-us-illinois; N...        None
# ...

# %%
locations = locations.drop([9682])
mask = locations['geolocation'].isnull()
locations.loc[960, 'corrected'] = 'AZ, US'
locations.loc[1163, 'corrected'] = 'NY, US'
locations.loc[1483, 'corrected'] = 'Denver, CO'
locations.loc[2035, 'corrected'] = 'NY, US'
locations.loc[11561, 'corrected'] = 'NJ, US'
locations.loc[12761, 'corrected'] = 'MA, US'
locations.loc[13237, 'corrected'] = 'NJ, US'
locations.loc[13650, 'corrected'] = 'NJ, US'
locations.loc[13699, 'corrected'] = 'NJ, US'
locations.loc[9475, 'corrected'] = 'CA, US'
locations.loc[9775, 'corrected'] = 'NY, US'
locations.loc[4569, 'corrected'] = 'IL, US'
locations.loc[3494, 'corrected'] = 'Research Triangle Park, Durham, NC'
locations.loc[2995, 'corrected'] = 'Washington, DC'
locations.loc[2995, 'corrected'] = 'Marycrest, NY'
locations.loc[5040, 'corrected'] = 'NAS Point Mogu, CA'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                  location geolocation           corrected
# 1119      Bethlehem Or Nyc Or Holmdel, NY        None
# 1884                    Mediacom Park, NY        None
# 3266                         Hooksett, AZ        None
# 3370      Purchase, Ny Or Phoenix, Az, NY        None
# 3640          Tacoma, Wa & Aurora, Co, WA        None
# 5040                  Point Mugu Nawc, CA        None  NAS Point Mogu, CA
# 5116           Trinton Falls,westbury, NJ        None
# 18321                   Arlington, Tx, NY        None
# 18919            St Louis Earnings Tx, MO        None
# 21426                     Or New York, DE        None
# 27845           Los Angeles Or Irvine, CA        None
# 33571    Princeton, Chicago, Sanjose,, CA        None
# 41505            Dallas, Sfo, Florida, CA        None
# 52177            St.louis, Charlotte,, MO        None
# 55102       ; North Americauskentucky, TN        None
# 57993  San Francisco, Oakland, Charlo, CA        None

# %%
locations.loc[2995, 'geolocation'] = None
mask = locations['geolocation'].isnull()
locations.loc[5040, 'corrected'] = 'Naval Base Ventura County, CA'
locations.loc[2995, 'corrected'] = 'Washington, DC'
locations.loc[1884, 'corrected'] = 'Marycrest, NY'
locations.loc[mask, 'geolocation'] = locations.loc[mask, 'corrected'].apply(geolocate)
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
#                                  location geolocation corrected
# 1119      Bethlehem Or Nyc Or Holmdel, NY        None
# 3266                         Hooksett, AZ        None
# 3370      Purchase, Ny Or Phoenix, Az, NY        None
# 3640          Tacoma, Wa & Aurora, Co, WA        None
# 5116           Trinton Falls,westbury, NJ        None
# 18321                   Arlington, Tx, NY        None
# 18919            St Louis Earnings Tx, MO        None
# 21426                     Or New York, DE        None
# 27845           Los Angeles Or Irvine, CA        None
# 33571    Princeton, Chicago, Sanjose,, CA        None
# 41505            Dallas, Sfo, Florida, CA        None
# 52177            St.louis, Charlotte,, MO        None
# 55102       ; North Americauskentucky, TN        None
# 57993  San Francisco, Oakland, Charlo, CA        None

# %%
locations = locations.dropna()
mask = locations['geolocation'].isnull()
locations[mask]
# Out:
# Empty DataFrame
# Columns: [location, geolocation, corrected]
# Index: []

# %%
locations['longitude'] = locations['geolocation'].apply(lambda x: x.longitude)
locations['latitude'] = locations['geolocation'].apply(lambda x: x.latitude)
locations
# Out:
# -c:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        location  \
# 0               Lake County, IL
# 1                Youngstown, OH
# 2             Detroit, MI 48202
# 3                    Towson, MD
# 4           Fort Lauderdale, FL
# 5                  New York, NY
# 6               San Antonio, TX
# 7                 San Diego, CA
# 8         Linthicum Heights, MD
# 11           New York, NY 10014
# 13                Arlington, VA
# ...

# %%
job_locations_strict = job_locations[['location', 'date_posted']]\
    .merge(locations[['location', 'latitude', 'longitude']], on = 'location')

# %%
job_locations_strict
# Out:
#                    location date_posted   latitude   longitude
# 0           Lake County, IL  2017-02-12  42.332599  -87.993985
# 1           Lake County, IL  2017-02-12  42.332599  -87.993985
# 2            Youngstown, OH  2017-02-12  41.099780  -80.649519
# 3            Youngstown, OH  2017-02-10  41.099780  -80.649519
# 4         Detroit, MI 48202  2017-02-12  42.348664  -83.056737
# 5         Detroit, MI 48202  2017-02-11  42.348664  -83.056737
# 6         Detroit, MI 48202  2017-02-11  42.348664  -83.056737
# 7         Detroit, MI 48202  2017-02-12  42.348664  -83.056737
# 8                Towson, MD  2017-02-12  39.401855  -76.602388
# 9                Towson, MD  2017-02-10  39.401855  -76.602388
# 10               Towson, MD  2017-02-12  39.401855  -76.602388
# 11               Towson, MD  2017-02-13  39.401855  -76.602388
# 12               Towson, MD  2017-02-13  39.401855  -76.602388
# 13               Towson, MD  2017-01-30  39.401855  -76.602388
# ...

# %%
job_locations_strict.to_csv('data/aggregator_job_locations.csv', index = False, columns = ['date_posted', 'latitude', 'longitude'])

# %%
job_locations_strict['date_posted'].max()
# Out:
# '2017-02-14'

# %%
job_locations_strict['date_posted'].min()
# Out:
# '2017-01-13'
